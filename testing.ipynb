# %%
import jax
from functools import partial
import optax
import flax.linen as nn
import jax.numpy as jnp

from src.models import create_model_cifar10
from src.data_loaders import load_cifar10

# %%
# Load data
train_dataset, validation_dataset, test_dataset = load_cifar10()
# Define a random number generator key (seed)
rng = jax.random.PRNGKey(0)
# Initialize model, optimizer, and other necessary components
model, weights = create_model_cifar10(rng)
optimizer = optax.sgd(learning_rate=0.001)
opt_state = optimizer.init(model)

# %%
for batch in train_dataset:
    input_data, target_data = batch
    
    prediction = model.apply(weights, input_data)
    break
# Out:
# 2024-04-14 16:35:34.638719: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# ---------------------------------------------------------------------------
# ScopeCollectionNotFound                   Traceback (most recent call last)
# Cell In[7], line 3
#       1 for batch in train_dataset:
#       2     input_data, target_data = batch
# ----> 3     prediction = model.apply(weights, input_data)
#       4     break
#
#     [... skipping hidden 6 frame]
#
# File ~/Documents/SoSe 2024/deep_neural_network_analysis/neural_network_analysis/src/models.py:10, in Cifar10CNN.__call__(self, x)
#       8 @nn.compact
#       9 def __call__(self, x):
# ---> 10     x = nn.Conv(features=32, kernel_size=(3, 3))(x)
#      11     x = nn.relu(x)
#      12     x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2))
#
#     [... skipping hidden 2 frame]
#
# File ~/miniforge3/envs/env1/lib/python3.10/site-packages/flax/linen/linear.py:638, in _Conv.__call__(self, inputs)
#     632 if self.mask is not None and self.mask.shape != kernel_shape:
#     633   raise ValueError(
#     634     'Mask needs to have the same shape as weights. '
#     635     f'Shapes are: {self.mask.shape}, {kernel_shape}'
#     636   )
# --> 638 kernel = self.param(
#     639   'kernel', self.kernel_init, kernel_shape, self.param_dtype
#     640 )
#     642 if self.mask is not None:
#     643   kernel *= self.mask
#
#     [... skipping hidden 1 frame]
#
# File ~/miniforge3/envs/env1/lib/python3.10/site-packages/flax/core/scope.py:988, in Scope.param(self, name, init_fn, unbox, *init_args, **init_kwargs)
#     986 if not self.is_mutable_collection('params'):
#     987   if self.is_collection_empty('params'):
# --> 988     raise errors.ScopeCollectionNotFound('params', name, self.path_text)
#     989   raise errors.ScopeParamNotFoundError(name, self.path_text)
#     990 value = init_fn(self.make_rng('params'), *init_args, **init_kwargs)
#
# ScopeCollectionNotFound: Tried to access "kernel" from collection "params" in "/Conv_0" but the collection is empty. (https://flax.readthedocs.io/en/latest/api_reference/flax.errors.html#flax.errors.ScopeCollectionNotFound)

# %%
input_data
# Out:
# <tf.Tensor: shape=(32, 32, 32, 3), dtype=float32, numpy=
# array([[[[0.43137255, 0.3529412 , 0.3647059 ],
#          [0.2784314 , 0.20392157, 0.22352941],
#          [0.32941177, 0.26666668, 0.2509804 ],
#          ...,
#          [0.54509807, 0.5176471 , 0.4745098 ],
#          [0.5882353 , 0.5568628 , 0.5137255 ],
#          [0.5137255 , 0.4862745 , 0.44705883]],
#
#         [[0.4509804 , 0.36862746, 0.34509805],
#          [0.2901961 , 0.19607843, 0.1764706 ],
#          [0.34117648, 0.23921569, 0.2       ],
#          ...,
#          [0.5647059 , 0.53333336, 0.49019608],
#          [0.5803922 , 0.54901963, 0.5058824 ],
#          [0.5529412 , 0.52156866, 0.47843137]],
#
#         [[0.3647059 , 0.27058825, 0.21568628],
#          [0.3372549 , 0.22745098, 0.16862746],
#          [0.39215687, 0.2627451 , 0.2       ],
#          ...,
#          [0.59607846, 0.5647059 , 0.52156866],
#          [0.5882353 , 0.56078434, 0.5176471 ],
#          [0.54509807, 0.5058824 , 0.4627451 ]],
#
#         ...,
#
#         [[0.5254902 , 0.35686275, 0.2784314 ],
#          [0.5176471 , 0.35686275, 0.2627451 ],
#          [0.5411765 , 0.3764706 , 0.27450982],
#          ...,
#          [0.6784314 , 0.5529412 , 0.47058824],
#          [0.7019608 , 0.5764706 , 0.49411765],
#          [0.69411767, 0.57254905, 0.49019608]],
#
#         [[0.5529412 , 0.38431373, 0.3019608 ],
#          [0.52156866, 0.35686275, 0.2627451 ],
#          [0.52156866, 0.35686275, 0.25490198],
#          ...,
#          [0.69803923, 0.57254905, 0.49019608],
#          [0.69411767, 0.5686275 , 0.4862745 ],
#          [0.69411767, 0.5764706 , 0.49411765]],
#
#         [[0.5529412 , 0.3882353 , 0.30588236],
#          [0.5529412 , 0.3882353 , 0.29411766],
#          [0.5529412 , 0.39215687, 0.2901961 ],
#          ...,
#          [0.6392157 , 0.5137255 , 0.43137255],
#          [0.6784314 , 0.5529412 , 0.47058824],
#          [0.69803923, 0.5764706 , 0.49803922]]],
#
#
#        [[[0.34901962, 0.24705882, 0.2784314 ],
#          [0.34509805, 0.24705882, 0.26666668],
#          [0.32941177, 0.22352941, 0.27450982],
#          ...,
#          [0.4       , 0.1882353 , 0.21568628],
#          [0.30980393, 0.19215687, 0.23921569],
#          [0.28235295, 0.20392157, 0.2627451 ]],
#
#         [[0.3019608 , 0.1882353 , 0.21960784],
#          [0.38431373, 0.25882354, 0.28235295],
#          [0.34509805, 0.22352941, 0.26666668],
#          ...,
#          [0.4509804 , 0.24705882, 0.27450982],
#          [0.31764707, 0.19607843, 0.24313726],
#          [0.2509804 , 0.16470589, 0.21568628]],
#
#         [[0.27450982, 0.14901961, 0.17254902],
#          [0.39215687, 0.23921569, 0.2627451 ],
#          [0.3764706 , 0.23529412, 0.2784314 ],
#          ...,
#          [0.47058824, 0.27450982, 0.3019608 ],
#          [0.3137255 , 0.19215687, 0.23529412],
#          [0.27058825, 0.17254902, 0.21176471]],
#
#         ...,
#
#         [[0.4862745 , 0.2627451 , 0.23921569],
#          [0.45490196, 0.2509804 , 0.23529412],
#          [0.39215687, 0.22352941, 0.20784314],
#          ...,
#          [0.36862746, 0.20392157, 0.19607843],
#          [0.36078432, 0.18431373, 0.16470589],
#          [0.38039216, 0.19215687, 0.16862746]],
#
#         [[0.5568628 , 0.31764707, 0.28627452],
#          [0.5254902 , 0.3019608 , 0.2901961 ],
#          [0.36078432, 0.1882353 , 0.18431373],
#          ...,
#          [0.37254903, 0.1882353 , 0.1882353 ],
#          [0.4392157 , 0.24313726, 0.23921569],
#          [0.4392157 , 0.23137255, 0.21960784]],
#
#         [[0.5882353 , 0.3647059 , 0.33333334],
#          [0.44705883, 0.2509804 , 0.24705882],
#          [0.2901961 , 0.14117648, 0.14901961],
#          ...,
#          [0.45490196, 0.2509804 , 0.23921569],
#          [0.45882353, 0.25490198, 0.2509804 ],
#          [0.4509804 , 0.24313726, 0.23529412]]],
#
#
#        [[[0.21568628, 0.21960784, 0.2       ],
#          [0.12156863, 0.1254902 , 0.10588235],
#          [0.16078432, 0.16470589, 0.14117648],
#          ...,
#          [0.2627451 , 0.27450982, 0.2627451 ],
#          [0.27058825, 0.2784314 , 0.2627451 ],
#          [0.30980393, 0.31764707, 0.30980393]],
#
#         [[0.15686275, 0.16078432, 0.14509805],
#          [0.11372549, 0.11764706, 0.09803922],
#          [0.16862746, 0.17254902, 0.14901961],
#          ...,
#          [0.43137255, 0.44313726, 0.44313726],
#          [0.4627451 , 0.47058824, 0.4509804 ],
#          [0.5254902 , 0.53333336, 0.5254902 ]],
#
#         [[0.0627451 , 0.06666667, 0.05490196],
#          [0.07450981, 0.07450981, 0.0627451 ],
#          [0.11372549, 0.11372549, 0.10196079],
#          ...,
#          [0.43529412, 0.4392157 , 0.4392157 ],
#          [0.47843137, 0.4862745 , 0.47058824],
#          [0.5411765 , 0.54901963, 0.5411765 ]],
#
#         ...,
#
#         [[0.84705883, 0.8666667 , 0.8862745 ],
#          [0.92941177, 0.9411765 , 0.96862745],
#          [0.6784314 , 0.69803923, 0.6862745 ],
#          ...,
#          [0.5137255 , 0.52156866, 0.46666667],
#          [0.4862745 , 0.49411765, 0.44313726],
#          [0.48235294, 0.49019608, 0.4392157 ]],
#
#         [[0.67058825, 0.6862745 , 0.6862745 ],
#          [0.9254902 , 0.9411765 , 0.972549  ],
#          [0.84705883, 0.87058824, 0.8784314 ],
#          ...,
#          [0.5411765 , 0.54901963, 0.49411765],
#          [0.5176471 , 0.5254902 , 0.4745098 ],
#          [0.5137255 , 0.52156866, 0.47058824]],
#
#         [[0.5372549 , 0.5568628 , 0.5176471 ],
#          [0.76862746, 0.79607844, 0.8039216 ],
#          [0.9254902 , 0.9529412 , 0.96862745],
#          ...,
#          [0.5529412 , 0.5647059 , 0.5058824 ],
#          [0.5529412 , 0.5647059 , 0.5058824 ],
#          [0.52156866, 0.5294118 , 0.47843137]]],
#
#
#        ...,
#
#
#        [[[0.00784314, 0.00784314, 0.00784314],
#          [0.00392157, 0.00392157, 0.00392157],
#          [0.00392157, 0.00392157, 0.00392157],
#          ...,
#          [0.00392157, 0.00392157, 0.00392157],
#          [0.        , 0.        , 0.        ],
#          [0.00392157, 0.00392157, 0.00392157]],
#
#         [[0.00784314, 0.00784314, 0.00784314],
#          [0.00392157, 0.00392157, 0.00392157],
#          [0.01568628, 0.01568628, 0.01568628],
#          ...,
#          [0.01176471, 0.01176471, 0.01176471],
#          [0.        , 0.        , 0.        ],
#          [0.00392157, 0.00392157, 0.00392157]],
#
#         [[0.01568628, 0.01568628, 0.01568628],
#          [0.01960784, 0.01960784, 0.01960784],
#          [0.1764706 , 0.17254902, 0.17254902],
#          ...,
#          [0.06666667, 0.06666667, 0.06666667],
#          [0.01568628, 0.01568628, 0.01568628],
#          [0.00392157, 0.00392157, 0.00392157]],
#
#         ...,
#
#         [[0.02352941, 0.01960784, 0.03137255],
#          [0.01568628, 0.00392157, 0.00784314],
#          [0.40784314, 0.4       , 0.3764706 ],
#          ...,
#          [0.2627451 , 0.26666668, 0.23921569],
#          [0.        , 0.        , 0.02352941],
#          [0.00392157, 0.00392157, 0.00392157]],
#
#         [[0.01176471, 0.00392157, 0.01176471],
#          [0.01960784, 0.01176471, 0.01176471],
#          [0.        , 0.        , 0.        ],
#          ...,
#          [0.00392157, 0.00392157, 0.00784314],
#          [0.01176471, 0.00784314, 0.03529412],
#          [0.00392157, 0.00392157, 0.00392157]],
#
#         [[0.00392157, 0.00392157, 0.00392157],
#          [0.00392157, 0.00392157, 0.00392157],
#          [0.00784314, 0.00784314, 0.00784314],
#          ...,
#          [0.00392157, 0.00392157, 0.00392157],
#          [0.00392157, 0.00392157, 0.00392157],
#          [0.00392157, 0.00392157, 0.00392157]]],
#
#
#        [[[0.8       , 0.92156863, 0.9607843 ],
#          [0.77254903, 0.9098039 , 0.94509804],
#          [0.7882353 , 0.8980392 , 0.9411765 ],
#          ...,
#          [0.1254902 , 0.1764706 , 0.18039216],
#          [0.11764706, 0.16078432, 0.16078432],
#          [0.13333334, 0.15686275, 0.16862746]],
#
#         [[0.8156863 , 0.94509804, 0.99215686],
#          [0.7764706 , 0.92156863, 0.9607843 ],
#          [0.7921569 , 0.90588236, 0.95686275],
#          ...,
#          [0.13333334, 0.18039216, 0.1882353 ],
#          [0.14509805, 0.18431373, 0.1882353 ],
#          [0.14901961, 0.1764706 , 0.18431373]],
#
#         [[0.8156863 , 0.95686275, 1.        ],
#          [0.78431374, 0.93333334, 0.98039216],
#          [0.8       , 0.9254902 , 0.98039216],
#          ...,
#          [0.1764706 , 0.22352941, 0.23529412],
#          [0.16862746, 0.21176471, 0.21568628],
#          [0.16470589, 0.19215687, 0.2       ]],
#
#         ...,
#
#         [[0.25490198, 0.35686275, 0.43529412],
#          [0.21568628, 0.3137255 , 0.39607844],
#          [0.2       , 0.3019608 , 0.38039216],
#          ...,
#          [0.4509804 , 0.5411765 , 0.6       ],
#          [0.41960785, 0.52156866, 0.5686275 ],
#          [0.5372549 , 0.62352943, 0.654902  ]],
#
#         [[0.2       , 0.29411766, 0.37254903],
#          [0.19607843, 0.2901961 , 0.36862746],
#          [0.19215687, 0.2901961 , 0.3647059 ],
#          ...,
#          [0.40784314, 0.5019608 , 0.56078434],
#          [0.38039216, 0.48235294, 0.5294118 ],
#          [0.38039216, 0.4627451 , 0.4862745 ]],
#
#         [[0.2784314 , 0.3529412 , 0.42352942],
#          [0.27450982, 0.34901962, 0.41960785],
#          [0.27450982, 0.3529412 , 0.41960785],
#          ...,
#          [0.44313726, 0.5176471 , 0.5686275 ],
#          [0.4627451 , 0.5372549 , 0.5803922 ],
#          [0.29803923, 0.34901962, 0.37254903]]],
#
#
#        [[[0.57254905, 0.65882355, 0.8117647 ],
#          [0.5686275 , 0.6509804 , 0.8039216 ],
#          [0.5764706 , 0.65882355, 0.8117647 ],
#          ...,
#          [0.50980395, 0.6431373 , 0.7764706 ],
#          [0.5137255 , 0.64705884, 0.78039217],
#          [0.52156866, 0.654902  , 0.7882353 ]],
#
#         [[0.5803922 , 0.6666667 , 0.8156863 ],
#          [0.5764706 , 0.6627451 , 0.80784315],
#          [0.5882353 , 0.6784314 , 0.8235294 ],
#          ...,
#          [0.5294118 , 0.65882355, 0.7882353 ],
#          [0.5254902 , 0.654902  , 0.78431374],
#          [0.5254902 , 0.654902  , 0.78431374]],
#
#         [[0.5764706 , 0.6666667 , 0.8039216 ],
#          [0.5686275 , 0.65882355, 0.7921569 ],
#          [0.57254905, 0.6627451 , 0.8       ],
#          ...,
#          [0.54901963, 0.67058825, 0.7921569 ],
#          [0.5411765 , 0.6627451 , 0.78431374],
#          [0.53333336, 0.654902  , 0.7764706 ]],
#
#         ...,
#
#         [[0.61960787, 0.68235296, 0.77254903],
#          [0.6117647 , 0.6745098 , 0.7647059 ],
#          [0.6156863 , 0.68235296, 0.77254903],
#          ...,
#          [0.6       , 0.6666667 , 0.75686276],
#          [0.6039216 , 0.6745098 , 0.7607843 ],
#          [0.5921569 , 0.68235296, 0.7607843 ]],
#
#         [[0.62352943, 0.6862745 , 0.78039217],
#          [0.6156863 , 0.6784314 , 0.77254903],
#          [0.62352943, 0.6862745 , 0.7764706 ],
#          ...,
#          [0.6156863 , 0.6784314 , 0.76862746],
#          [0.6039216 , 0.6784314 , 0.7647059 ],
#          [0.59607846, 0.6862745 , 0.76862746]],
#
#         [[0.6156863 , 0.6784314 , 0.76862746],
#          [0.60784316, 0.67058825, 0.7607843 ],
#          [0.6156863 , 0.6784314 , 0.7647059 ],
#          ...,
#          [0.59607846, 0.65882355, 0.7490196 ],
#          [0.6       , 0.67058825, 0.75686276],
#          [0.5882353 , 0.6745098 , 0.75686276]]]], dtype=float32)>
